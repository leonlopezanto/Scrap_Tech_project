# %% [markdown]
# # Gestor de tablas
#
# ### Llegados a este punto y una vez realizadas las extracciones crearemos una tabla acumulada para cada página web. La tabla acumulada será la:
#
# # <div align="center">  TABLA MAESTRA </div>
#
# ## La maravillosa tabla maestra contiene TODA LA INFORMACIÓN NECESARIA que se debe presentar a la interfaz web.
#
# La tabla maestra se nutre de tablas submaestras para cada araña. En principio para PcComponentes habrá una submaestra y para Wipoid habrá otra. Estas tablas submaestras se nutrirán y actualizarán con información del último scrap realizado, de manera que se actualizarán constantemente tras cada etapa de scrap.
#
# Para crear una tabla acumulada utilizaremos la última tabla extraída y la añadiremos a una tabla actual. Después utilizamos tabla-1 para ir añadiendo los componentes actuales

# %%
import pandas as pd

import sys
sys.path.append('../../')
import Loader
from datetime import datetime

def get_fecha(tipo = 'normal'):
    return datetime.now().strftime("%d-%b-%Y (%H:%M:%S)") if(tipo == 'normal') else datetime.now().strftime("%H-%M_%d-%m")


#Cargamos las dos ultimas tablas
actual = 'actual.json'
ant = 'anterior.json'

#Carga en nuestra app
# l = Loader()
# #Cargador de datasets 
# actual = Loader.cargar_datos(actual)

actual = pd.read_json(actual, lines=True)
ant = pd.read_json(ant, lines=True)

# %%
actual
# Out:
#                                                  nombre  \
# 0                                        MSI Z590-A PRO
# 1                                  Asus PRO H510M-C/CSM
# 2                                        MSI Z390-A PRO
# 3                                  MSI B450M Mortar Max
# 4                                    Asus PRIME H410M-E
# ...                                                 ...
# 4730              WD My Passport 4TB 2.5" USB 3.0 Negro
# 4731  Toshiba Canvio Advance HDTCA40ER3CA 4TB 2.5" U...
# 4732                     WD Red Pro 3.5" 4TB NAS SATA 3
# 4733     WD Blue 1TB 5400rpm 3.5" SATA3 Reacondicionado
# 4734                    WD Desktop Mainstream 2TB SATA3
#
#                            id_item  reacondicionado  precio     categoria  \
# 0                     911-7D09-04S            False  189.90   Placas Base
# 1                  90MB17K0-M0EAYC            False   78.95   Placas Base
# 2                     911-7B98-001            False  121.90   Placas Base
# 3                 B450M MORTAR MAX            False   79.98   Placas Base
# 4                  90MB13H0-M0EAY0            False   69.95   Placas Base
# ...                            ...              ...     ...           ...
# 4730            WDBYFT0040BBK-WESN            False  123.00  Discos Duros
# 4731                  HDTCA40ER3CA            False  109.88  Discos Duros
# 4732                    WD4003FFBX            False  147.13  Discos Duros
# 4733  WD10EZRZ-RAS_Reacondicionado             True   43.14  Discos Duros
# 4734            WDBMMA0020HNC-ERSN            False  105.59  Discos Duros
#
#                   extraccion  \
# 0     19-May-2021 (17:31:59)
# 1     19-May-2021 (17:32:01)
# 2     19-May-2021 (17:32:02)
# 3     19-May-2021 (17:32:03)
# 4     19-May-2021 (17:32:04)
# ...                      ...
# 4730  19-May-2021 (19:12:46)
# 4731  19-May-2021 (19:12:47)
# 4732  19-May-2021 (19:12:49)
# 4733  19-May-2021 (19:12:50)
# 4734  19-May-2021 (19:12:51)
#
#                                                     url  disponible
# 0          https://www.pccomponentes.com/msi-z590-a-pro        True
# 1     https://www.pccomponentes.com/asus-pro-h510m-c...        True
# 2          https://www.pccomponentes.com/msi-z390-a-pro        True
# 3     https://www.pccomponentes.com/msi-b450m-mortar...        True
# 4      https://www.pccomponentes.com/asus-prime-h410m-e        True
# ...                                                 ...         ...
# 4730  https://www.pccomponentes.com/wd-my-passport-4...        True
# 4731  https://www.pccomponentes.com/toshiba-canvio-a...        True
# 4732  https://www.pccomponentes.com/wd-red-pro-35-4t...        True
# 4733  https://www.pccomponentes.com/wd-blue-1tb-5400...        True
# 4734  https://www.pccomponentes.com/wd-desktop-mains...        True
#
# [4735 rows x 8 columns]

# %%
ant
# Out:
#                                                  nombre             id_item  \
# 0                                        MSI Z590-A PRO        911-7D09-04S
# 1                                  Asus PRO H510M-C/CSM     90MB17K0-M0EAYC
# 2                                        MSI Z390-A PRO        911-7B98-001
# 3                                  MSI B450M Mortar Max    B450M MORTAR MAX
# 4                                    Asus PRIME H410M-E     90MB13H0-M0EAY0
# ...                                                 ...                 ...
# 4755             Adata HD710 Pro 1TB 2.5" USB 3.2 Negro   AHD710P-1TU31-CBK
# 4756          Seagate Backup Plus Slim 2TB USB 3.0 Azul          2R1AP9-572
# 4757              WD My Passport 4TB 2.5" USB 3.0 Negro  WDBYFT0040BBK-WESN
# 4758  Toshiba Canvio Advance HDTCA40ER3CA 4TB 2.5" U...        HDTCA40ER3CA
# 4759                   HP Enterprise 2.5" 600GB 12G SAS          872477-B21
#
#       reacondicionado  precio     categoria              extraccion  \
# 0               False  189.90   Placas Base  19-May-2021 (14:35:58)
# 1               False   78.95   Placas Base  19-May-2021 (14:35:58)
# 2               False  121.90   Placas Base  19-May-2021 (14:36:00)
# 3               False   79.98   Placas Base  19-May-2021 (14:36:01)
# 4               False   69.95   Placas Base  19-May-2021 (14:36:02)
# ...               ...     ...           ...                     ...
# 4755            False   63.65  Discos Duros  19-May-2021 (16:17:34)
# 4756            False   80.06  Discos Duros  19-May-2021 (16:17:35)
# 4757            False  123.00  Discos Duros  19-May-2021 (16:17:36)
# 4758            False  109.88  Discos Duros  19-May-2021 (16:17:38)
# 4759            False  184.40  Discos Duros  19-May-2021 (16:17:39)
#
#                                                     url  disponible
# 0          https://www.pccomponentes.com/msi-z590-a-pro        True
# 1     https://www.pccomponentes.com/asus-pro-h510m-c...        True
# 2          https://www.pccomponentes.com/msi-z390-a-pro        True
# 3     https://www.pccomponentes.com/msi-b450m-mortar...        True
# 4      https://www.pccomponentes.com/asus-prime-h410m-e        True
# ...                                                 ...         ...
# 4755  https://www.pccomponentes.com/adata-hd710-pro-...        True
# 4756  https://www.pccomponentes.com/seagate-backup-p...        True
# 4757  https://www.pccomponentes.com/wd-my-passport-4...        True
# 4758  https://www.pccomponentes.com/toshiba-canvio-a...        True
# 4759  https://www.pccomponentes.com/hp-enterprise-25...        True
#
# [4760 rows x 8 columns]

# %%
print("Elementos en actual: " , actual.count())
print("Elementos en ant: ", ant.count())
# Out:
# Elementos en actual:  nombre             4735
# id_item            4735
# reacondicionado    4735
# precio             4735
# categoria          4735
# extraccion         4735
# url                4735
# disponible         4735
# dtype: int64
# Elementos en ant:  nombre             4760
# id_item            4760
# reacondicionado    4760
# precio             4760
# categoria          4760
# extraccion         4760
# url                4760
# disponible         4760
# dtype: int64

# %% [markdown]
# #### En PCComponentes, los elementos que ya no estén es porque no aparecen en la web, por tanto ponemos no disponibles, ya que si entramos a su enlace, seguirán apareciendo.
#
# Funciones:
#
# merge how=outer -> une las filas de uno a otro y encaso de que las filas sean idénticas, no las duplica
#
# merge -> une las filas que son identicas de uno a otro

# %% [markdown]
# ### PCComponentes

# %% [markdown]
# #### Buscamos los elementos comunes de anterior y actual para ver si el precio ha variado
#
#
#
# Si el precio de anterior > actual -> BAJADA DE PRECIO, FIESTA\
# Si el precio de anterio  < actual -> SUBIDA DE PRECIO, MIERDA\
# Si el precio de anterior = actual -> SE MANTIENE Y NO SE NOTIFICA
#
# Según ocurra esto, el campo, precio_actualizado = baja/sube/mantiene

# %% [markdown]
# Obtenemos los elementos comunes entre anterior y actual y reseteamos el indice para evitar problemas

# %%
#ant = ant[(ant.id_item.isin(actual.id_item))][['id_item','precio']].reset_index()
#act = actual[(actual.id_item.isin(ant.id_item))][['id_item','precio']].reset_index()
an = ant[(ant.id_item.isin(actual.id_item))].reset_index()
ac = actual[(actual.id_item.isin(ant.id_item))].reset_index()

# %% [markdown]
# Nos quedamos con los componentes que se repiten en ambos y añadimos la nueva columna a actual

# %%
import numpy as np
# Lista de condiciones
conditions = [
    (an['precio'] < ac['precio']),
    (an['precio'] > ac['precio']),
    (an['precio'] == ac['precio'])
    ]
# lista de valores a asignar a las condiciones
values = ['sube', 'baja', 'mantiene']

#Utilizamos el metodo select de Numpy
ac['precio_upd'] = np.select(conditions, values)
ac
# Out:
#       index                                             nombre  \
# 0         0                                     MSI Z590-A PRO
# 1         1                               Asus PRO H510M-C/CSM
# 2         2                                     MSI Z390-A PRO
# 3         3                               MSI B450M Mortar Max
# 4         4                                 Asus PRIME H410M-E
# ...     ...                                                ...
# 4608   4730              WD My Passport 4TB 2.5" USB 3.0 Negro
# 4609   4731  Toshiba Canvio Advance HDTCA40ER3CA 4TB 2.5" U...
# 4610   4732                     WD Red Pro 3.5" 4TB NAS SATA 3
# 4611   4733     WD Blue 1TB 5400rpm 3.5" SATA3 Reacondicionado
# 4612   4734                    WD Desktop Mainstream 2TB SATA3
#
#                            id_item  reacondicionado  precio     categoria  \
# 0                     911-7D09-04S            False  189.90   Placas Base
# 1                  90MB17K0-M0EAYC            False   78.95   Placas Base
# 2                     911-7B98-001            False  121.90   Placas Base
# 3                 B450M MORTAR MAX            False   79.98   Placas Base
# 4                  90MB13H0-M0EAY0            False   69.95   Placas Base
# ...                            ...              ...     ...           ...
# 4608            WDBYFT0040BBK-WESN            False  123.00  Discos Duros
# 4609                  HDTCA40ER3CA            False  109.88  Discos Duros
# 4610                    WD4003FFBX            False  147.13  Discos Duros
# 4611  WD10EZRZ-RAS_Reacondicionado             True   43.14  Discos Duros
# 4612            WDBMMA0020HNC-ERSN            False  105.59  Discos Duros
#
#                   extraccion  \
# 0     19-May-2021 (17:31:59)
# 1     19-May-2021 (17:32:01)
# 2     19-May-2021 (17:32:02)
# 3     19-May-2021 (17:32:03)
# 4     19-May-2021 (17:32:04)
# ...                      ...
# 4608  19-May-2021 (19:12:46)
# 4609  19-May-2021 (19:12:47)
# 4610  19-May-2021 (19:12:49)
# 4611  19-May-2021 (19:12:50)
# 4612  19-May-2021 (19:12:51)
#
#                                                     url  disponible precio_upd
# 0          https://www.pccomponentes.com/msi-z590-a-pro        True   mantiene
# 1     https://www.pccomponentes.com/asus-pro-h510m-c...        True   mantiene
# 2          https://www.pccomponentes.com/msi-z390-a-pro        True   mantiene
# 3     https://www.pccomponentes.com/msi-b450m-mortar...        True   mantiene
# 4      https://www.pccomponentes.com/asus-prime-h410m-e        True   mantiene
# ...                                                 ...         ...        ...
# 4608  https://www.pccomponentes.com/wd-my-passport-4...        True       sube
# 4609  https://www.pccomponentes.com/toshiba-canvio-a...        True       sube
# 4610  https://www.pccomponentes.com/wd-red-pro-35-4t...        True       sube
# 4611  https://www.pccomponentes.com/wd-blue-1tb-5400...        True       baja
# 4612  https://www.pccomponentes.com/wd-desktop-mains...        True       baja
#
# [4613 rows x 10 columns]

# %% [markdown]
# Ya tenemos la tabla con precios actualizados de los elementos que se repiten. Ahora necesitamos la tabla con elementos que NO se repiten.

# %%
del ac['index']
ac.shape
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\scrapTech\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-edf1dde033d7> in <module>
# ----> 1 del ac['index']
#       2 ac.shape
#
# ~\anaconda3\envs\scrapTech\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3964             # there was no match, this call should raise the appropriate
#    3965             # exception:
# -> 3966             loc = self.axes[-1].get_loc(key)
#    3967             self._mgr.idelete(loc)
#    3968
#
# ~\anaconda3\envs\scrapTech\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'index'

# %% [markdown]
# #### Buscamos los elementos de anterior que no están en actual (NO DISPONIBLES)
# Componentes que no están en actual pero sí en anterior
#
#     pccomponentes -> los que ya no aparecen en la tabla se ponen a No Disponibles (PCcomponentes no muestra lo que no hay activo pero la web sigue existiendo, así que se pone a no disponible)

# %%
#Df con los componentes de anterior que ya no están en actual. Componentes No_Disponibles
eliminados = ant[(~ant.id_item.isin(actual.id_item))]

print('Mostrando elementos de anterior que no están en actual')
eliminados
# Out:
# Mostrando elementos de anterior que no están en actual
#                                                nombre  \
# 65                                   Gigabyte H410M H
# 309                            Gigabyte Z390 Gaming X
# 624     Lian-Li Uni Fan SL120 RGB Kit x3 120mm Blanco
# 628            Lian-Li Uni Fan SL120 RGB Kit x3 120mm
# 653                             MSI MEG Z490 GODLIKE
# ...                                               ...
# 4600                Toshiba DT01ACA200 2TB SATA3 64MB
# 4601  Intenso Memory Board 1TB 2.5" USB 3.0 Antracita
# 4602                     Toshiba L200 2.5" 1TB SATA 3
# 4603   Seagate Backup Plus Portable 5TB USB 3.0 Negro
# 4618              PNY Nvidia Quadro P400 V2 2GB GDDR5
#
#                           id_item  reacondicionado  precio          categoria  \
# 65                   H410M H R1.0            False   59.99        Placas Base
# 309              GA-Z390 GAMING X            False  127.90        Placas Base
# 624   UNI Fan SL 120 Triple White            False   99.00        Ventilación
# 628   UNI Fan SL 120 Triple Black            False   89.99        Ventilación
# 653                  911-7C70-05S            False  619.90        Placas Base
# ...                           ...              ...     ...                ...
# 4600                   DT01ACA200            False   66.74       Discos Duros
# 4601                      6028660            False   53.05       Discos Duros
# 4602                 HDWJ110UZSVA            False   60.35       Discos Duros
# 4603                  STHP5000400            False  149.13       Discos Duros
# 4618                 VCQP400V2-PB            False  141.12  Tarjetas Gráficas
#
#                   extraccion  \
# 65    19-May-2021 (14:37:18)
# 309   19-May-2021 (14:42:28)
# 624   19-May-2021 (14:49:08)
# 628   19-May-2021 (14:49:13)
# 653   19-May-2021 (14:49:45)
# ...                      ...
# 4600  19-May-2021 (16:14:02)
# 4601  19-May-2021 (16:14:04)
# 4602  19-May-2021 (16:14:05)
# 4603  19-May-2021 (16:14:07)
# 4618  19-May-2021 (16:14:26)
#
#                                                     url  disponible
# 65       https://www.pccomponentes.com/gigabyte-h410m-h        True
# 309   https://www.pccomponentes.com/gigabyte-z390-ga...        True
# 624   https://www.pccomponentes.com/lian-li-uni-fan-...        True
# 628   https://www.pccomponentes.com/lian-li-uni-fan-...        True
# 653   https://www.pccomponentes.com/msi-meg-z490-god...        True
# ...                                                 ...         ...
# 4600  https://www.pccomponentes.com/toshiba-dt01aca2...        True
# 4601  https://www.pccomponentes.com/intenso-memory-b...        True
# 4602  https://www.pccomponentes.com/toshiba-l200-25-...        True
# 4603  https://www.pccomponentes.com/seagate-backup-p...        True
# 4618  https://www.pccomponentes.com/pny-nvidia-quadr...        True
#
# [147 rows x 8 columns]

# %%
#eliminados.is_copy = None
#Elimina la excepcion. NO nos importa
pd.set_option('mode.chained_assignment', None)
#actualizamos campo disponible
eliminados['disponible'] = False
#actualizamos campo update
eliminados['update'] = get_fecha()

#Unimos los archivos que no estan disponibles a la tabla maestra de pccomponentes
#maestraPC = actual.merge(eliminados, how='outer')
#variable maestraPC con elementos no disponibles y disponibles actualizados y update actualizado
#maestraPC

#Necesita aún lo del precio....

eliminados['precio_upd'] = 'mantiene'

eliminados.shape
# Out:
# (147, 10)

# %% [markdown]
# Los elementos que han sido descartados de la web es que han dejado de estar disponibles. disponible=False, update=fecha_actual
# precio_upd=LO VAMOS A PONER A MANTENER POR AHORA -> ABRÁ QUE MODIFICAR EL SCRAPING PARA DEJAR DE TENER NULOS Y PONER A NO DISPONIBLES LOS QUE NO ESTÉN EN VENTA

# %%
eliminados
# Out:
#                                                nombre  \
# 65                                   Gigabyte H410M H
# 309                            Gigabyte Z390 Gaming X
# 624     Lian-Li Uni Fan SL120 RGB Kit x3 120mm Blanco
# 628            Lian-Li Uni Fan SL120 RGB Kit x3 120mm
# 653                             MSI MEG Z490 GODLIKE
# ...                                               ...
# 4600                Toshiba DT01ACA200 2TB SATA3 64MB
# 4601  Intenso Memory Board 1TB 2.5" USB 3.0 Antracita
# 4602                     Toshiba L200 2.5" 1TB SATA 3
# 4603   Seagate Backup Plus Portable 5TB USB 3.0 Negro
# 4618              PNY Nvidia Quadro P400 V2 2GB GDDR5
#
#                           id_item  reacondicionado  precio          categoria  \
# 65                   H410M H R1.0            False   59.99        Placas Base
# 309              GA-Z390 GAMING X            False  127.90        Placas Base
# 624   UNI Fan SL 120 Triple White            False   99.00        Ventilación
# 628   UNI Fan SL 120 Triple Black            False   89.99        Ventilación
# 653                  911-7C70-05S            False  619.90        Placas Base
# ...                           ...              ...     ...                ...
# 4600                   DT01ACA200            False   66.74       Discos Duros
# 4601                      6028660            False   53.05       Discos Duros
# 4602                 HDWJ110UZSVA            False   60.35       Discos Duros
# 4603                  STHP5000400            False  149.13       Discos Duros
# 4618                 VCQP400V2-PB            False  141.12  Tarjetas Gráficas
#
#                   extraccion  \
# 65    19-May-2021 (14:37:18)
# 309   19-May-2021 (14:42:28)
# 624   19-May-2021 (14:49:08)
# 628   19-May-2021 (14:49:13)
# 653   19-May-2021 (14:49:45)
# ...                      ...
# 4600  19-May-2021 (16:14:02)
# 4601  19-May-2021 (16:14:04)
# 4602  19-May-2021 (16:14:05)
# 4603  19-May-2021 (16:14:07)
# 4618  19-May-2021 (16:14:26)
#
#                                                     url  disponible  \
# 65       https://www.pccomponentes.com/gigabyte-h410m-h       False
# 309   https://www.pccomponentes.com/gigabyte-z390-ga...       False
# 624   https://www.pccomponentes.com/lian-li-uni-fan-...       False
# 628   https://www.pccomponentes.com/lian-li-uni-fan-...       False
# 653   https://www.pccomponentes.com/msi-meg-z490-god...       False
# ...                                                 ...         ...
# 4600  https://www.pccomponentes.com/toshiba-dt01aca2...       False
# 4601  https://www.pccomponentes.com/intenso-memory-b...       False
# 4602  https://www.pccomponentes.com/toshiba-l200-25-...       False
# 4603  https://www.pccomponentes.com/seagate-backup-p...       False
# 4618  https://www.pccomponentes.com/pny-nvidia-quadr...       False
#
#                       update precio_upd
# 65    19-May-2021 (22:12:46)   mantiene
# 309   19-May-2021 (22:12:46)   mantiene
# 624   19-May-2021 (22:12:46)   mantiene
# 628   19-May-2021 (22:12:46)   mantiene
# 653   19-May-2021 (22:12:46)   mantiene
# ...                      ...        ...
# 4600  19-May-2021 (22:12:46)   mantiene
# 4601  19-May-2021 (22:12:46)   mantiene
# 4602  19-May-2021 (22:12:46)   mantiene
# 4603  19-May-2021 (22:12:46)   mantiene
# 4618  19-May-2021 (22:12:46)   mantiene
#
# [147 rows x 10 columns]

# %% [markdown]
# #### Buscamos los elementos de actual que no están en anterior (NUEVOS)

# %%
nuevos = actual[(~actual.id_item.isin(ant.id_item))]

nuevos['precio_upd'] = 'Nuevo'

nuevos.head(30)
# Out:
#                                                  nombre  \
# 503                               Gigabyte H410M S2H V2
# 608        NZXT Kraken X53 Kit de Refrigeración Líquida
# 609   Corsair iCUE SP120 RGB ELITE Performance 120 m...
# 658                                 ASRock B560M-ITX/AC
# 660              MSI MAG B550M BAZOOKA  Reacondicionado
# 661             MSI B550M PRO-VDH WIFI  Reacondicionado
# 662                    Gigabyte H410M H Reacondicionado
# 663              Gigabyte B450M DS3H V2 Reacondicionado
# 664                                        Asus H110M-R
# 1026                                Asrock B365M-ITX/AC
# 1033                     Asrock Fatal1ty B360 Gaming K4
# 1249  Cooler Master MWE Gold 750 V2 750W 80 Plus Gol...
# 1307  Nox Hummer 850W 80+ Bronze Modular Reacondicio...
# 1308  L-Link LL-PS-800-80+S 800W 80 Plus Silver Reac...
# 1309       Kolink Core RGB 600W 80 Plus Reacondicionado
# 1310  Hiditec PSX Fuente de Alimentación 500W Reacon...
# 1311  Hiditec EVO800 Fuente de Alimentación 800W PFC...
# 1312  Gigabyte Aorus P750W 750W 80 Plus Gold Modular...
# 1313  EVGA Supernova 1000 G3 1000W 80 Plus Gold Modu...
# 1314  EVGA 750GA Supernova 750W 80 Plus Gold Modular...
# 1315  DeepCool DQ850-M-V2L 850W 80 Plus Gold Modular...
# 1316  Corsair HX750 750W 80 Plus Platinum Modular Re...
# 1317  Corsair CX Series CX650F RGB 650W 80 Plus Bron...
# 1318    Cooler Master MWE White V2 600W Reacondicionado
# 1319   Cooler Master MWE Bronze V2 650W Reacondicionado
# 1320  Cooler Master MWE 650 Bronze V2 650W 80 Plus B...
# 1321  Thermaltake Toughpower PF1 ARGB 850W 80 Plus P...
# 1322  BitFenix Fórmula Gold Fuente de Alimentación 5...
# 1323  Seasonic Focus PX650 650W 80 Plus Platinum Ful...
# 1324                   Corsair VS550 550W 80 Plus White
#
#                                      id_item  reacondicionado  precio  \
# 503                             H410M S2H V2            False   83.11
# 608                              RL-KRX53-01            False  129.99
# 609                            CO-9050109-WW            False   69.99
# 658                         90-MXBEZ0-A0UAYZ            False  136.57
# 660         911-7C95-08S-RAS_Reacondicionado             True   85.00
# 661         911-7C95-09S-RAS_Reacondicionado             True   85.15
# 662         H410M H R1.0-RAS_Reacondicionado             True   49.20
# 663       GAB45MSH2-00-G-RAS_Reacondicionado             True   52.25
# 664                          90MB0QN0-M0ECY0            False   55.99
# 1026                            B365M-ITX/ac            False  107.69
# 1033                        90-MXB6Y0-A0UAYZ            False  139.96
# 1249                       MPE-7501-AFAAG-EU            False  134.12
# 1307           NXHM850BZ-RAS_Reacondicionado             True   66.60
# 1308      LL-PS-800-80+S-RAS_Reacondicionado             True   42.50
# 1309          KL-C600RGB-RAS_Reacondicionado             True   42.50
# 1310          PS00123599-RAS_Reacondicionado             True   13.15
# 1311                               PSU010016            False   50.00
# 1312       GP-AP750GM-EU-RAS_Reacondicionado             True   98.50
# 1313      220-G3-1000-X2-RAS_Reacondicionado             True  130.00
# 1314      220-GA-0750-X2-RAS_Reacondicionado             True  100.95
# 1315   DP-GD-DQ850-M-V2L-RAS_Reacondicionado             True   93.50
# 1316       CP-9020137-EU-RAS_Reacondicionado             True  115.75
# 1317       CP-9020217-EU-RAS_Reacondicionado             True   75.10
# 1318   MPE-6001-ACABW-EU-RAS_Reacondicionado             True   42.00
# 1319   MPE-6501-ACAAB-EU-RAS_Reacondicionado             True   55.00
# 1320  MPE-6501-ACABW-BEU-RAS_Reacondicionado             True   52.25
# 1321     PS-TPD-0850F3FAPE-1_Reacondicionado             True  185.40
# 1322     BP-FM550ULAG-9R-RAS_Reacondicionado             True   60.70
# 1323        FOCUS-PX-650-RAS_Reacondicionado             True  112.80
# 1324                           CP-9020171-EU            False   54.99
#
#                  categoria              extraccion  \
# 503            Placas Base  19-May-2021 (17:42:37)
# 608            Ventilación  19-May-2021 (17:44:47)
# 609            Ventilación  19-May-2021 (17:44:48)
# 658            Placas Base  19-May-2021 (17:45:49)
# 660            Placas Base  19-May-2021 (17:45:51)
# 661            Placas Base  19-May-2021 (17:45:52)
# 662            Placas Base  19-May-2021 (17:45:53)
# 663            Placas Base  19-May-2021 (17:45:55)
# 664            Placas Base  19-May-2021 (17:45:55)
# 1026           Placas Base  19-May-2021 (17:53:37)
# 1033           Placas Base  19-May-2021 (17:53:45)
# 1249  Fuentes Alimentación  19-May-2021 (17:58:26)
# 1307  Fuentes Alimentación  19-May-2021 (17:59:38)
# 1308  Fuentes Alimentación  19-May-2021 (17:59:38)
# 1309  Fuentes Alimentación  19-May-2021 (17:59:40)
# 1310  Fuentes Alimentación  19-May-2021 (17:59:42)
# 1311  Fuentes Alimentación  19-May-2021 (17:59:42)
# 1312  Fuentes Alimentación  19-May-2021 (17:59:44)
# 1313  Fuentes Alimentación  19-May-2021 (17:59:45)
# 1314  Fuentes Alimentación  19-May-2021 (17:59:46)
# 1315  Fuentes Alimentación  19-May-2021 (17:59:48)
# 1316  Fuentes Alimentación  19-May-2021 (17:59:49)
# 1317  Fuentes Alimentación  19-May-2021 (17:59:51)
# 1318  Fuentes Alimentación  19-May-2021 (17:59:52)
# 1319  Fuentes Alimentación  19-May-2021 (17:59:53)
# 1320  Fuentes Alimentación  19-May-2021 (17:59:54)
# 1321  Fuentes Alimentación  19-May-2021 (17:59:55)
# 1322  Fuentes Alimentación  19-May-2021 (17:59:57)
# 1323  Fuentes Alimentación  19-May-2021 (17:59:58)
# 1324  Fuentes Alimentación  19-May-2021 (17:59:58)
#
#                                                     url  disponible precio_upd
# 503   https://www.pccomponentes.com/gigabyte-h410m-s...        True      Nuevo
# 608   https://www.pccomponentes.com/nzxt-kraken-x53-...        True      Nuevo
# 609   https://www.pccomponentes.com/corsair-icue-sp1...        True      Nuevo
# 658   https://www.pccomponentes.com/asrock-b560m-itx-ac        True      Nuevo
# 660   https://www.pccomponentes.com/msi-mag-b550m-ba...        True      Nuevo
# 661   https://www.pccomponentes.com/msi-b550m-pro-vd...        True      Nuevo
# 662   https://www.pccomponentes.com/gigabyte-h410m-h...        True      Nuevo
# 663   https://www.pccomponentes.com/gigabyte-b450m-d...        True      Nuevo
# 664          https://www.pccomponentes.com/asus-h110m-r        True      Nuevo
# 1026  https://www.pccomponentes.com/asrock-b365m-itx-ac        True      Nuevo
# 1033  https://www.pccomponentes.com/asrock-fatal1ty-...        True      Nuevo
# 1249  https://www.pccomponentes.com/cooler-master-mw...        True      Nuevo
# 1307  https://www.pccomponentes.com/nox-hummer-850w-...        True      Nuevo
# 1308  https://www.pccomponentes.com/l-link-ll-ps-800...        True      Nuevo
# 1309  https://www.pccomponentes.com/kolink-core-rgb-...        True      Nuevo
# 1310  https://www.pccomponentes.com/hiditec-psx-fuen...        True      Nuevo
# 1311  https://www.pccomponentes.com/hiditec-evo800-f...        True      Nuevo
# 1312  https://www.pccomponentes.com/gigabyte-aorus-p...        True      Nuevo
# 1313  https://www.pccomponentes.com/evga-supernova-1...        True      Nuevo
# 1314  https://www.pccomponentes.com/evga-750ga-super...        True      Nuevo
# 1315  https://www.pccomponentes.com/deepcool-dq850-m...        True      Nuevo
# 1316  https://www.pccomponentes.com/corsair-hx750-75...        True      Nuevo
# 1317  https://www.pccomponentes.com/corsair-cx-serie...        True      Nuevo
# 1318  https://www.pccomponentes.com/cooler-master-mw...        True      Nuevo
# 1319  https://www.pccomponentes.com/cooler-master-mw...        True      Nuevo
# 1320  https://www.pccomponentes.com/cooler-master-mw...        True      Nuevo
# 1321  https://www.pccomponentes.com/thermaltake-toug...        True      Nuevo
# 1322  https://www.pccomponentes.com/bitfenix-frmula-...        True      Nuevo
# 1323  https://www.pccomponentes.com/seasonic-focus-p...        True      Nuevo
# 1324  https://www.pccomponentes.com/corsair-vs550-55...        True      Nuevo

# %%
maestraPC = pd.concat([nuevos,ac,eliminados])

# %%
maestraPC.sort_values(by=['id_item']).reset_index()
maestraPC.shape
# Out:
# (4882, 10)

# %% [markdown]
# maestraPC
